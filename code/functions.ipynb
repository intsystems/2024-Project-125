# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from hypers import weight_hypers
from hypers import alpha_hypers

# %%
def weights_exp4_func(x):
    return np.exp(-x / 4)
    
np.sum(weights_exp4_func(np.arange(1, 3000)))
# Out:
# 3.5208116641877987

# %%
np.sum(weight_hypers["slow"].func(np.arange(1, 3000)))
# Out:
# 0.8718636345374337

# %%
1 / (np.exp(1/4) - 1)
# Out:
# 3.5208116641877996

# %%
grid = np.arange(1, 10)
for key, wh in weight_hypers.items():
    plt.plot(grid, wh.func(grid), label=key)
plt.legend()
