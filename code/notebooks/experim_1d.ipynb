# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

# warnings.filterwarnings('ignore')
plt.rcParams['figure.dpi'] = 80

import sys
sys.path.insert(0, '..')

import os
from pathlib import Path

from hypers import weight_hypers
from hypers import alpha_hypers 

from experiment import Params
from experiment import run_experiments
from experiment import load_experiments
from experiment import draw_logs
from experiment import experiments_to_df

from analysis import draw_several

# %% [markdown]
# ### Эксперимент

# %%
dir = '../results/'
file = 'experim_52.json'

seeds = np.arange(4) + 101

params = Params(series_type = "default",
                from_start = False,
                a = -40,
                b = 40,
                dim = 10,
                low = -10,
                high = 10,
                clip = (-40, 40),
                workers_num = 5,
                length = 2000,
                lower_bound = 50,
                upper_bound = 300,
                alternating=True)

different_noises = [1]
different_windows = [10]

# different_wf = ["simple_101", "const", "diverge_05"]
different_af = ["const_1100", "const_1500", "shift_10", "shift_100", "shift_1000"] \
+ ["const_11000", "const_15000", "const_110000", "const_150000"] \
+ ["simple_05", "simple_15", "simple_2", "exp_3", "log"] 

interesting = set()

# for key_w in different_wf:
#     interesting.add((key_w, "start", "default"))

for key_a in different_af:
    interesting.add(("default", "start", key_a))


experiments, df = run_experiments(dir+file, seeds, params, different_noises, different_windows, interesting)
with open(dir + Path('info_' + file).with_suffix('').as_posix(), 'w') as f:
    f.write(_ih[2])
    
# experiments, df = load_experiments(dir+file)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:05<00:00, 39.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.60it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:05<00:00, 39.38it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:05<00:00, 39.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:05<00:00, 39.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:05<00:00, 39.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2570/2570 [01:04<00:00, 39.56it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.76it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.60it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2927/2927 [01:24<00:00, 34.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 2497/2497 [01:01<00:00, 40.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.57it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:31<00:00, 33.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.40it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.39it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.56it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.39it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:31<00:00, 33.19it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:30<00:00, 33.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 3037/3037 [01:31<00:00, 33.34it/s]

# %%
df
# Out:
#    noise_var train_window                weight_function mixing_type  \
# 7          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 2          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 12         1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 3          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 11         1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 0          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 1          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 6          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 5          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 13         1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 8          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 9          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 4          1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
# 10         1           10  1 / ((x + 1) * (ln(x + 1))^2)       start
#
#      alpha_function       mean   random_0   random_1   random_2   random_3
# 7      1 / (x + 10)  175411.17  153920.85  130233.56  219983.67  197506.59
# 2     1 / (x + 100)  173760.98  152310.77  129263.36  217268.82  196200.98
# 12   1 / (x + 1000)  162129.20  141004.79  121766.24  199869.46  185876.32
# 3           1 / 100  220008.81  200857.08  163182.89  269554.19   246441.1
# 11          1 / 500  198094.83  176533.81   149531.3   241021.5  225292.72
# 0          1 / 1000  184324.73  162364.91  139756.56  223105.75   212071.7
# 1          1 / 5000  147561.46  127766.33  112710.78  177522.92  172245.81
# 6         1 / 10000  136414.42  118833.49  105515.62  164249.74  157058.85
# 5         1 / 50000  130783.65  116084.15  103198.86  158471.31  145380.28
# 13  1 / (x + 1)^0.5  245494.10  234235.64  172751.55  306252.82   268736.4
# 8   1 / (x + 1)^1.5  130339.21  114406.27  103454.24  158184.59  145311.75
# 9     1 / (x + 1)^2  136029.09  120498.72  105793.31  166044.11  151780.23
# 4     1 / ln(x + 1)  534269.18  475592.81  541901.15  560087.36  559495.42
# 10      1 / e^(x/3)  136413.87  120993.38  105880.37  166647.04  152134.69

# %%
# enumerated = [(num, experiment) for num, experiment in enumerate(experiments)]
# for num, experiment in enumerated[::7]:
#     draw_logs(experiment.logs, show=["master", "ideal"], title=f"Experiment №{num},  regret = {experiment.regret:.1f}", fig_size=(12, 5))

# %%
experiments0, df0 = load_experiments(dir+file)

# %%
shift = 80 * 2
vital = merged[shift + 0: shift + 12]
anls = [experiment.logs for experiment in vital]
labels = [str(experiment.train_window) + " + " + experiment.key_a + " + " + experiment.mixing_type + " + " + experiment.key_w for experiment in vital]
colors = [None] * 16
draw_several(from_start=False, logs=anls, labels=labels, colors=colors, fig_size=(12, 7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 shift = 80 * 2
# ----> 2 vital = merged[shift + 0: shift + 12]
#       3 anls = [experiment.logs for experiment in vital]
#       4 labels = [str(experiment.train_window) + " + " + experiment.key_a + " + " + experiment.mixing_type + " + " + experiment.key_w for experiment in vital]
#
# NameError: name 'merged' is not defined

# %%
# df_w = df[df["alpha_function"] == alpha_hypers["default"].repr].iloc[:,:6]
# df_w

# %%
# print(df_r.to_latex(index=False, float_format="%.2f"))
# df[["noise_var", "train_window", "regret"]].groupby(["noise_var", "train_window"]).mean()
